# %%
import os
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
dit = 0.3                          # detector integration time in s
flux_mag0 = 8.999e+10              # [e-/s] HCI-L long, mag 0 (Jan 21, 2020)
mag_star = 5                       # star magnitude
mag_planet = 20                    # planet magnitude

# %%
os.chdir(os.path.normpath(os.path.expandvars('$HOME/heeps_metis/output_files')))
star = fits.getdata('scao_only/onaxis_PSF_L_RAVC.fits')
planet = fits.getdata('point_planet/onaxis_PSF_L_RAVC.fits')

# %%
star *= dit * flux_mag0 * 10**(-0.4*mag_star)
planet *= dit * flux_mag0 * 10**(-0.4*mag_planet)
plt.imshow(np.log(star[-1] + planet[0]));

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
# Enable interactive plot
# %matplotlib notebook
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display
plt.rcParams['animation.ffmpeg_path'] = '/Users/cdelacroix/CODE/ffmpeg'
fig, ax = plt.subplots()
line, = ax.plot([])   # A tuple unpacking to unpack the only plot
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(-1.1, 1.1)
x = np.linspace(0, 2*np.pi, 100)
def animate(frame_num):
    y = np.sin(x + 2*np.pi * frame_num/100)
    line.set_data((x, y))
    return line
anim = FuncAnimation(fig, animate, frames=100, interval=5)
video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()                   # avoid plotting a spare static plot
#%matplotlib widget
#%matplotlib inline
# Out:
# <div id='bcc6ea8a-f315-4d70-b9aa-e96e4b7324a6'></div>
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...
