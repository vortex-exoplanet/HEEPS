# %% [markdown]
# # Contrast curve grid database plotter
# Author: Gilles Orban de Xivry
#
# Date : 11/5/2026
#
# Code generation assisted by Claude Sonnet 4.6

# %% [markdown]
# ## Setup

# %%
# ── dependencies ────────────────────────────────────────────────────────────
from IPython.display import display
import sys
sys.path.append('../heeps/util/')
from database_tools import build_download_widget

# %%
# ── credentials prompt & download ───────────────────────────────────────────
# DB_PATH = None   # will be set after successful download

# ATTACHMENT_URL = ("https://svn.mpia.de/metis-science/bin/download/Main/"
#     "Transverse%20Working%20Groups/WebHome/20260511_GOX_test.txt")
ATTACHMENT_URL = ("https://svn.mpia.de/metis-science/bin/download/Main/"
    "Transverse%20Working%20Groups/WebHome/20260511_GOX_DB_VVC_contrast_curve_grid.zip")

archive_fname = "../cc_grid_tmp.zip"
folder_db = "../2026_DB_VVC_contrast_grid"

display(build_download_widget(ATTACHMENT_URL, archive_fname, folder_db))

# %% [markdown]
# ## Plotting tool

# %%
# %matplotlib widget
from itables import init_notebook_mode
init_notebook_mode(all_interactive=True)
import itables.options as opt
opt.style = "table-layout:auto;width:auto"

import pathlib
import sys
sys.path.append('../heeps/util/')
from database_tools import list_contrast_grid_db, build_contrast_plotter
# Out:
# <script>
#     let is_dark_theme = function () {
#         // Jupyter Lab
#         if ('jpThemeLight' in document.body.dataset)
#             return (document.body.dataset.jpThemeLight === "false");
#
#         // VS Code
#         if ('vscodeThemeKind' in document.body.dataset)
#             return document.body.dataset.vscodeThemeKind.includes('dark');
#
#         // Jupyter Book
#         if ('theme' in document.documentElement.dataset)
#             return document.documentElement.dataset.theme.includes('dark');
#
#         // Default
#         return window.matchMedia('(prefers-color-scheme: dark)').matches;
#     }
#
#     if (is_dark_theme()) {
#         document.documentElement.classList.add('dark');
#     }
#     else {
#         document.documentElement.classList.remove('dark');
#     }
# </script>
# ...

# %%
db_name = '2026_contrast_curve_grid'
# db_path= '/mnt/disk20tb/METIS/DATABASE_SACRED/'
# DB_PATH = db_path + db_name
DB_PATH = pathlib.Path('.db_path.txt').read_text().strip()
# ── Run ──────────────────────────────────────────────────────────────────────
df_cc = list_contrast_grid_db(DB_PATH+'/'+db_name, verbose=True)

# Plotting UI
build_contrast_plotter(df_cc, DB_PATH+'/'+db_name, show_status=False)
# Out:
# [list_contrast_grid_db] Found 238 run(s) matching the filters in /home/gorban/github/HEEPS_latest/2026_DB_VVC_contrast_grid/2026_contrast_curve_grid
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
